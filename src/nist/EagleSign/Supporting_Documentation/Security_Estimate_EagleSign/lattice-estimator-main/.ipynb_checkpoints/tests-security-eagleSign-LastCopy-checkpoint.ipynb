# %%
from estimator import *
from estimator.lwe_parameters import *
from estimator.nd import *

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 2")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=512, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Longterm secret key recovery (G,D) from E=(A+D)G^{-1}")
print("To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error") 
print("Uniform Distribution  for G and D")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
p=512
q=12289
k=2
l=1
etag=6
etad=6
EagleSign2LPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.Uniform(-etag,etag),
    Xe=NoiseDistribution.Uniform(-etad,etad),
    m=k*p,
    tag="EagleSign2LPk")

print("p:",p, ", q:", q,", k:", k, ", l:", l,   ", etag:", etag, ", etad:", etad)
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
r=LWE.estimate(EagleSign2LPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=512, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Longterm secret key recovery (G,D) from E=(A+D)G^{-1}
# To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error
# Uniform Distribution  for G and D
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 512 , q: 12289 , k: 2 , l: 1 , etag: 6 , etad: 6
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# bkw                  :: rop: ≈2^230.5, m: ≈2^206.9, mem: ≈2^207.9, b: 15, t1: 1, t2: 17, ℓ: 14, #cod: 444, #top: 4, #test: 49, tag: coded-bkw
# usvp                 :: rop: ≈2^159.2, red: ≈2^159.2, δ: 1.003606, β: 461, d: 1113, tag: usvp
# bdd                  :: rop: ≈2^155.6, red: ≈2^154.6, svp: ≈2^154.6, β: 444, η: 478, d: 1120, tag: bdd
# bdd_hybrid           :: rop: ≈2^155.6, red: ≈2^154.6, svp: ≈2^154.6, β: 444, η: 478, ζ: 0, |S|: 1, d: 1144, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^332.6, red: ≈2^332.6, svp: ≈2^193.6, β: 461, η: 2, ζ: 0, |S|: 1, d: 1159, prob: ≈2^-171.1, ↻: ≈2^173.3, tag: hybrid
# dual                 :: rop: ≈2^165.9, mem: ≈2^99.0, m: 663, β: 481, d: 1175, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^162.1, mem: ≈2^158.7, m: 648, β: 466, d: 1143, ↻: 1, ζ: 17, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 2")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=512, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2")
print("To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y_1 is the secret and y2 is the error ") 
print("with uniform Distribution  for y_2 and sparse distribution for y_1")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

p=512
q=12289
k=2
l=1
t=140
etay2=64
etay1=1
EagleSign2EPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.SparseTernary(p,t/2,t/2),
    Xe=NoiseDistribution.Uniform(-etay2,etay2),
    m=k*p,
    tag="EagleSign2EPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,  ", t:", t,  ", etay1:", etay1, ", etay2:", etay2)

r=LWE.estimate(EagleSign2EPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=512, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2
# To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y_1 is the secret and y2 is the error
# with uniform Distribution  for y_2 and sparse distribution for y_1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 512 , q: 12289 , k: 2 , l: 1 , t: 140 , etay1: 1 , etay2: 64
# Algorithm functools.partial(<function dual_hybrid at 0x7f98644e4700>, red_cost_model=<estimator.reduction.MATZOV object at 0x7f98645f0730>, mitm_optimization=True) on LWEParameters(n=512, q=12289, Xs=D(σ=0.52), Xe=D(σ=37.24), m=1024, tag='EagleSign2EPk') failed with β = 79 > d = 65
# bkw                  :: rop: ≈2^154.6, m: ≈2^142.1, mem: ≈2^139.3, b: 10, t1: 0, t2: 11, ℓ: 9, #cod: 413, #top: 0, #test: 99, tag: coded-bkw
# usvp                 :: rop: ≈2^164.5, red: ≈2^164.5, δ: 1.003489, β: 483, d: 849, tag: usvp
# bdd                  :: rop: ≈2^171.5, red: ≈2^171.2, svp: ≈2^169.1, β: 511, η: 530, d: 683, tag: bdd
# bdd_hybrid           :: rop: ≈2^174.9, red: ≈2^173.2, svp: ≈2^174.4, β: 511, η: 549, ζ: 0, |S|: 1, d: 1202, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^226.4, red: ≈2^225.8, svp: ≈2^224.8, β: 446, η: 2, ζ: 256, |S|: ≈2^267.8, d: 889, prob: ≈2^-69.1, ↻: ≈2^71.3, tag: hybrid
# dual                 :: rop: ≈2^173.9, mem: ≈2^105.0, m: 378, β: 513, d: 890, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^160.9, mem: ≈2^150.9, m: 342, β: 439, d: 782, ↻: 146, ζ: 72, h1: 14, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 3 :")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=1024, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Longterm secret key recovery (G,D) from E=(A+D)G^{-1}")
print("To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error") 
print("Uniform Distribution  for G and D")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
p=1024
q=12289
k=1
l=1
etag=1
etad=1
EagleSign3LPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.Uniform(-etag,etag),
    Xe=NoiseDistribution.Uniform(-etad,etad),
    m=k*p,
    tag="EagleSign3LPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,   ", etag:", etag, ", etad:", etad)
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

r=LWE.estimate(EagleSign3LPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 3 :
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=1024, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Longterm secret key recovery (G,D) from E=(A+D)G^{-1}
# To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error
# Uniform Distribution  for G and D
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 1024 , q: 12289 , k: 1 , l: 1 , etag: 1 , etad: 1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# bkw                  :: rop: ≈2^274.8, m: ≈2^261.5, mem: ≈2^262.5, b: 19, t1: 0, t2: 21, ℓ: 18, #cod: 900, #top: 0, #test: 128, tag: coded-bkw
# usvp                 :: rop: ≈2^230.1, red: ≈2^230.1, δ: 1.002634, β: 712, d: 1896, tag: usvp
# bdd                  :: rop: ≈2^226.5, red: ≈2^225.6, svp: ≈2^225.5, β: 696, η: 732, d: 1874, tag: bdd
# bdd_hybrid           :: rop: ≈2^226.6, red: ≈2^225.6, svp: ≈2^225.5, β: 696, η: 732, ζ: 0, |S|: 1, d: 1900, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^340.8, red: ≈2^340.0, svp: ≈2^339.5, β: 711, η: 2, ζ: 262, |S|: ≈2^415.3, d: 1653, prob: ≈2^-108.3, ↻: ≈2^110.5, tag: hybrid
# dual                 :: rop: ≈2^239.5, mem: ≈2^151.0, m: 920, β: 742, d: 1944, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^228.1, mem: ≈2^223.7, m: 883, β: 701, d: 1856, ↻: 1, ζ: 51, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 3")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=1024, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2")
print("To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error ") 
print("Uniform Distribution  for y_2 and sparse distribution for y_1")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
p=1024
q=12289
k=1
l=1
t=140
etay2=64
etay1=1
EagleSign3EPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.SparseTernary(p,t/2,t/2),
    Xe=NoiseDistribution.Uniform(-etay2,etay2),
    m=k*p,
    tag="EagleSign3EPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,  ", t:", t,  ", etay1:", etay1, ", etay2:", etay2)

r=LWE.estimate(EagleSign3EPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 3
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=1024, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2
# To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error
# Uniform Distribution  for y_2 and sparse distribution for y_1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 1024 , q: 12289 , k: 1 , l: 1 , t: 140 , etay1: 1 , etay2: 64
# Algorithm functools.partial(<function dual_hybrid at 0x7f98644e4700>, red_cost_model=<estimator.reduction.MATZOV object at 0x7f98645f0730>, mitm_optimization=True) on LWEParameters(n=1024, q=12289, Xs=D(σ=0.37), Xe=D(σ=37.24), m=1024, tag='EagleSign3EPk') failed with β = 79 > d = 65
# bkw                  :: rop: ≈2^245.5, m: ≈2^233.1, mem: ≈2^234.1, b: 17, t1: 0, t2: 9, ℓ: 16, #cod: 757, #top: 0, #test: 268, tag: coded-bkw
# usvp                 :: rop: ≈2^301.7, red: ≈2^301.7, δ: 1.002088, β: 972, d: 1503, tag: usvp
# bdd                  :: rop: ≈2^315.6, red: ≈2^315.5, svp: ≈2^310.3, β: 1026, η: 1035, d: 1241, tag: bdd
# bdd_hybrid           :: rop: ≈2^313.9, red: ≈2^311.9, svp: ≈2^313.5, β: 739, η: 780, ζ: 287, |S|: 1, d: 1655, prob: ≈2^-72.4, ↻: ≈2^74.6, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^427.2, red: ≈2^427.2, svp: ≈2^420.2, β: 1007, η: 2, ζ: 512, |S|: ≈2^566.6, d: 1537, prob: ≈2^-113.5, ↻: ≈2^115.7, tag: hybrid
# dual                 :: rop: ≈2^320.9, mem: ≈2^208.0, m: 551, β: 1037, d: 1575, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^261.7, mem: ≈2^228.4, m: 459, β: 713, d: 1095, ↻: ≈2^31.0, ζ: 388, h1: 23, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 5")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=1024, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Longterm secret key recovery (G,D) from E=(A+D)G^{-1}")
print("To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error") 
print("Uniform Distribution  for G and D")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

p=1024
q=12289
k=1
l=2
etag=1
etad=1
EagleSign4LPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.Uniform(-etag,etag),
    Xe=NoiseDistribution.Uniform(-etad,etad),
    m=p*k,
    tag="EagleSign4LPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,   ", etag:", etag, ", etad:", etad)
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

r=LWE.estimate(EagleSign4LPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 5
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=1024, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Longterm secret key recovery (G,D) from E=(A+D)G^{-1}
# To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error
# Uniform Distribution  for G and D
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 1024 , q: 12289 , k: 1 , l: 2 , etag: 1 , etad: 1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# bkw                  :: rop: ≈2^533.9, m: ≈2^519.6, mem: ≈2^520.6, b: 38, t1: 0, t2: 21, ℓ: 37, #cod: 1808, #top: 0, #test: 261, tag: coded-bkw
# usvp                 :: rop: ≈2^500.1, red: ≈2^500.1, δ: 1.001373, β: 1673, d: 3070, tag: usvp
# bdd                  :: rop: ≈2^494.5, red: ≈2^493.3, svp: ≈2^493.6, β: 1649, η: 1687, d: 3073, tag: bdd
# bdd_hybrid           :: rop: ≈2^494.5, red: ≈2^493.3, svp: ≈2^493.6, β: 1649, η: 1687, ζ: 0, |S|: 1, d: 3073, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^783.9, red: ≈2^782.9, svp: ≈2^782.9, β: 1671, η: 2, ζ: 601, |S|: ≈2^952.3, d: 2472, prob: ≈2^-282.0, ↻: ≈2^284.2, tag: hybrid
# dual                 :: rop: ≈2^527.8, mem: ≈2^352.0, m: 1024, β: 1768, d: 3072, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^496.8, mem: ≈2^493.6, m: 1024, β: 1657, d: 2969, ↻: 1, ζ: 103, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 5")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=1024, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2")
print("To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error ") 
print("Uniform Distribution  for y_2 and sparse distribution for y_1")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
p=1024
q=12289
k=1
l=2
t=86
etay2=32
etay1=1
EagleSign4EPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.SparseTernary(p,t/2,t/2),
    Xe=NoiseDistribution.Uniform(-etay2,etay2),
    m=k*p,
    tag="EagleSign4EPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,  ", t:", t,   ", etay1:", etay1, ", etay2:", etay2)

r=LWE.estimate(EagleSign4EPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 5
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=1024, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2
# To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error
# Uniform Distribution  for y_2 and sparse distribution for y_1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 1024 , q: 12289 , k: 1 , l: 2 , t: 86 , etay1: 1 , etay2: 32
# Algorithm functools.partial(<function dual_hybrid at 0x7f98644e4700>, red_cost_model=<estimator.reduction.MATZOV object at 0x7f98645f0730>, mitm_optimization=True) on LWEParameters(n=2048, q=12289, Xs=D(σ=0.29), Xe=D(σ=18.76), m=1024, tag='EagleSign4EPk') failed with β = 79 > d = 69
# arora-gb             :: rop: ≈2^inf, dreg: 192, mem: ≈2^715.1, t: 32, m: ≈2^764.3, tag: arora-gb, ↻: ≈2^754.3, ζ: 1877, |S|: ≈2^427.1, prop: ≈2^-324.9
# bkw                  :: rop: ≈2^388.2, m: ≈2^373.5, mem: ≈2^370.4, b: 27, t1: 0, t2: 12, ℓ: 26, #cod: 1491, #top: 0, #test: 557, tag: coded-bkw
# usvp                 :: rop: ≈2^545.2, red: ≈2^545.2, δ: 1.001277, β: 1835, d: 2841, tag: usvp
# bdd                  :: rop: ≈2^540.3, red: ≈2^539.9, svp: ≈2^538.4, β: 1816, η: 1846, d: 2802, tag: bdd
# bdd_hybrid           :: rop: ≈2^461.5, red: ≈2^459.6, svp: ≈2^461.1, β: 870, η: 911, ζ: 1024, |S|: 1, d: 1894, prob: ≈2^-183.3, ↻: ≈2^185.5, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^405.5, red: ≈2^404.5, svp: ≈2^404.5, β: 881, η: 2, ζ: 1568, |S|: ≈2^510.4, d: 1364, prob: ≈2^-126.3, ↻: ≈2^128.5, tag: hybrid
# dual                 :: rop: ≈2^579.3, mem: ≈2^389.0, m: 925, β: 1952, d: 2973, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^400.8, mem: ≈2^318.7, m: 676, β: 1033, d: 1619, ↻: ≈2^80.0, ζ: 1105, h1: 31, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 3+")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=512, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Longterm secret key recovery (G,D) from E=(A+D)G^{-1}")
print("To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error") 
print("Uniform Distribution  for G and D")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

p=512
q=12289
k=2
l=2
etag=2
etad=1
EagleSign5LPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.Uniform(-etag,etag),
    Xe=NoiseDistribution.Uniform(-etad,etad),
    m=p*k,
    tag="EagleSign5LPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,   ", etag:", etag, ", etad:", etad)
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")

r=LWE.estimate(EagleSign5LPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 3+
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=512, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Longterm secret key recovery (G,D) from E=(A+D)G^{-1}
# To estimate the security level, E=(A+D)G^{-1} is viewed (as usual) as a LWE instance where G is the secret and D is the error
# Uniform Distribution  for G and D
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 512 , q: 12289 , k: 2 , l: 2 , etag: 2 , etad: 1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# bkw                  :: rop: ≈2^288.1, m: ≈2^274.9, mem: ≈2^275.9, b: 20, t1: 0, t2: 19, ℓ: 19, #cod: 899, #top: 0, #test: 133, tag: coded-bkw
# usvp                 :: rop: ≈2^242.8, red: ≈2^242.8, δ: 1.002515, β: 758, d: 1850, tag: usvp
# bdd                  :: rop: ≈2^239.2, red: ≈2^238.1, svp: ≈2^238.3, β: 741, η: 778, d: 1820, tag: bdd
# bdd_hybrid           :: rop: ≈2^239.3, red: ≈2^238.2, svp: ≈2^238.3, β: 741, η: 778, ζ: 0, |S|: 1, d: 1944, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^360.2, red: ≈2^359.3, svp: ≈2^359.0, β: 759, η: 2, ζ: 279, |S|: ≈2^442.2, d: 1683, prob: ≈2^-114.2, ↻: ≈2^116.5, tag: hybrid
# dual                 :: rop: ≈2^253.4, mem: ≈2^159.4, m: 909, β: 792, d: 1933, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^240.7, mem: ≈2^236.2, m: 870, β: 746, d: 1840, ↻: 1, ζ: 54, tag: dual_hybrid

# %%
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("EagleSign Security estimate")
print("Nist security level 3+ ")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ring dimension p=512, underlying field modulus q=12289")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
print("Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2")
print("To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error ") 
print("Uniform Distribution  for y_2 and sparse distribution for y_1")
print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
p=512
q=12289
k=2
l=2
t=90
etay2=32
etay1=1
EagleSign5EPk = LWEParameters(n=p*l,
    q=q,
    Xs=NoiseDistribution.SparseTernary(p,t/2,t/2),
    Xe=NoiseDistribution.Uniform(-etay2,etay2),
    m=k*p,
    tag="EagleSign5EPk")
print("p:",p, ", q:", q,", k:", k, ", l:", l,  ", t:", t, ", etay1:", etay1, ", etay2:", etay2)

r=LWE.estimate(EagleSign5EPk)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# EagleSign Security estimate
# Nist security level 3+
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ring dimension p=512, underlying field modulus q=12289
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Ephemeral secret key recovery (y_1,y_2) from P=A.y_1+y_2
# To estimate the security level, P=A.y_1+y_2 is viewed  as a LWE instance where y1 is the secret and y2 is the error
# Uniform Distribution  for y_2 and sparse distribution for y_1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# p: 512 , q: 12289 , k: 2 , l: 2 , t: 90 , etay1: 1 , etay2: 32
# Algorithm functools.partial(<function dual_hybrid at 0x7f98644e4700>, red_cost_model=<estimator.reduction.MATZOV object at 0x7f98645f0730>, mitm_optimization=True) on LWEParameters(n=1024, q=12289, Xs=D(σ=0.42), Xe=D(σ=18.76), m=1024, tag='EagleSign5EPk') failed with β = 79 > d = 69
# arora-gb             :: rop: ≈2^inf, dreg: 199, mem: ≈2^745.3, t: 32, m: ≈2^594.4, tag: arora-gb, ↻: ≈2^584.4, ζ: 845, |S|: ≈2^372.9, prop: ≈2^-209.3
# bkw                  :: rop: ≈2^249.3, m: ≈2^235.7, mem: ≈2^234.5, b: 17, t1: 0, t2: 12, ℓ: 16, #cod: 806, #top: 0, #test: 218, tag: coded-bkw
# usvp                 :: rop: ≈2^288.0, red: ≈2^288.0, δ: 1.002172, β: 922, d: 1592, tag: usvp
# bdd                  :: rop: ≈2^295.0, red: ≈2^294.9, svp: ≈2^289.3, β: 949, η: 960, d: 1376, tag: bdd
# bdd_hybrid           :: rop: ≈2^297.4, red: ≈2^296.3, svp: ≈2^296.6, β: 949, η: 986, ζ: 0, |S|: 1, d: 2049, prob: 1, ↻: 1, tag: hybrid
# bdd_mitm_hybrid      :: rop: ≈2^369.8, red: ≈2^369.3, svp: ≈2^368.0, β: 795, η: 2, ζ: 511, |S|: ≈2^460.2, d: 1485, prob: ≈2^-114.6, ↻: ≈2^116.8, tag: hybrid
# dual                 :: rop: ≈2^305.1, mem: ≈2^196.0, m: 642, β: 979, d: 1666, ↻: 1, tag: dual
# dual_hybrid          :: rop: ≈2^265.0, mem: ≈2^242.6, m: 558, β: 764, d: 1311, ↻: ≈2^19.9, ζ: 271, h1: 25, tag: dual_hybrid

# %%
from lwe_estimator import  *

# %%
def sigma(n, k,l, delta, deltaprime):
    return 32+n*(l*math.ceil(math.log2(1+2*delta))+k*math.ceil(math.log2(1+2*deltaprime)))/8
def pk(n,k,l, q):
    return 32+n*(k*l*math.ceil(math.log2(q)))/8
def size(q):
    return math.ceil(math.log2(q))


#level 2
q2=12289; k2=2; l2=1; t2=140 ;  tau2=18; etay22=64; etay12=1; etag2=6; etad2=6;  delta2=l2*(t2+tau2)*etag2;  delta2prime=l2*(t2+tau2)*etad2 +etay22;  beta2=max(2*delta2,2*delta2prime); pk2= pk(512,k2,l2, q2);
sigma2=sigma(512,k2,l2, delta2, delta2prime); 

#level 3
q3=12289; k3=1; l3=1; t3=140 ;  tau3=38; etay23=64; etay13=1; etag3=1; etad3=1;  delta3=l3*(t3+tau3)*etag3;  delta3prime=l3*(t3+tau3)*etad3 +etay23;  beta3=max(2*delta3,2*delta3prime); pk3= pk(1024,k3,l3, q3);
sigma3=sigma(1024,k3,l3, delta3, delta3prime); 

#level 5

q41=12289; k41=1; l41=2; t41=86 ;  tau41=18; etay241=32; etay141=1; etag41=1; etad41=1;  delta41=l41*(t41+tau41)*etag41;  delta41prime=l41*(t41+tau41)*etad41 +etay241;  beta41=max(2*delta41,2*delta41prime); pk41= pk(1024,k41,l41, q41);
sigma41=sigma(1024,k41,l41, delta41, delta41prime); 

#level 3+               
q5=12289; k5=2; l5=2; t5=90 ;  tau5=28; etay25=32; etay15=1; etag5=1; etad5=1; delta5=l5*(t5+tau5)*etag5;  delta5prime=l5*(t5+tau5)*etad5 +etay25;  beta5=max(2*delta5,2*delta5prime); pk5= pk(512,k5,l5, q5);
sigma5=sigma(512,k5,l5, delta5, delta5prime); 

print("2","n:512", "q:", q2,"(delta, deltaprime, beta)=:", delta2, delta2prime, beta2,  ", (q-1)/16:",  (q2-1)/16,   ", pk:", pk2, ", sigma:", sigma2)
print("3","n:1024", "q:", q3,"(delta, deltaprime, beta)=:", delta3, delta3prime, beta3,  ", (q-1)/16:",  (q3-1)/16,   ", pk:", pk3, ", sigma:", sigma3)
print("5","n:1024", "q:", q41,"(delta, deltaprime, beta)=:", delta41, delta5prime, beta41,  ", (q-1)/16:",  (q41-1)/16,   ", pk:", pk41, ", sigma:", sigma41)
print("3+","n:512", "q:", q5,"(delta, deltaprime, beta)=:", delta5, delta4prime, beta5,  ", (q-1)/16:",  (q5-1)/16,   ", pk:", pk5, ", sigma:", sigma5)
# Out:
# 2 n:512 q: 12289 (delta, deltaprime, beta)=: 948 1012 2024 , (q-1)/16: 768 , pk: 1824 , sigma: 2144
# 3 n:1024 q: 12289 (delta, deltaprime, beta)=: 178 242 484 , (q-1)/16: 768 , pk: 1824 , sigma: 2336
# 5 n:1024 q: 12289 (delta, deltaprime, beta)=: 208 268 480 , (q-1)/16: 768 , pk: 3616 , sigma: 3488
# 3+ n:512 q: 12289 (delta, deltaprime, beta)=: 236 722 536 , (q-1)/16: 768 , pk: 3616 , sigma: 2464
